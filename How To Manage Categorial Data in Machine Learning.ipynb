# %% [markdown]
# # Manage Categorial Data in Machine Learning

# %%
process of transforming non-numeric categorical data into a numerical format 
that can be used by machine learning algorithms.

# %% [markdown]
# # How To Manage Categorial Data in Machine Learning

# %% [markdown]
# # Here's are the scheme for managing the categorial data

# %% [markdown]
# # One-Hot Encoding

# %% [markdown]
# # Dummy coding scheme

# %% [markdown]
# # Effect coding scheme

# %% [markdown]
# # lets give example for each

# %% [markdown]
# ![Screenshot%202024-11-19%20062825.png](attachment:Screenshot%202024-11-19%20062825.png)

# %%
One-Hot Encoding :- Creates binary columns for each category

# %% [markdown]
# ![Screenshot%202024-11-19%20063228.png](attachment:Screenshot%202024-11-19%20063228.png)

# %%
its work like 
if data has 3 category such as red blue and green
when category matches with input so the output in binary format would be 1 
if not match then it would be 0

# %% [markdown]
# ![Screenshot%202024-11-19%20063616.png](attachment:Screenshot%202024-11-19%20063616.png)

# %%
Dummy coding scheme :- Dummy coding is a method used to represent categorical variables with multiple levels
                       in a format that can be used in statistical models

# %% [markdown]
# ![Screenshot%202024-11-19%20063922.png](attachment:Screenshot%202024-11-19%20063922.png)

# %% [markdown]
# # concepts is as like  one encoding scheme But in different method

# %% [markdown]
# # 1)by droping category , 2)sometimes individuals category

# %%
Effect coding scheme :- Effect coding is a method used in statistical analysis to represent categorical variables.

# %% [markdown]
# ![Screenshot%202024-11-19%20064625.png](attachment:Screenshot%202024-11-19%20064625.png)

# %% [markdown]
# # concept like Dummy coding scheme but just reverse the roll for 0 with -1

# %%
for ex.

# %% [markdown]
# ![Screenshot%202024-11-19%20065448.png](attachment:Screenshot%202024-11-19%20065448.png)

# %% [markdown]
# # just replace the 0-0 value by -1 only when there is two zero at a time
